# %%
import cv2
import numpy as np
import math
from matplotlib import pyplot as plt

# %%
#https://stackoverflow.com/questions/58751101/count-number-of-cells-in-the-image

img = cv2.imread("images/02.png")

# Convert to grey scale
original = img.copy()
img_bgr = img.copy()
img_bgr[:,:,0] = 0 # blue
img_bgr[:,:,1] = 0 # green
gray = cv2.cvtColor(img_bgr,cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(10,10))
plt.imshow(gray, cmap='gray')

# %%
# apply masking
mask = cv2.inRange(img_bgr, np.array([0,0,50]), np.array([0,0,255]))
plt.figure(figsize=(10,10))
plt.imshow(mask, cmap="gray")

# %%
# filtering, removing noise
kernel = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (3,3))
opening = cv2.morphologyEx(mask, cv2.MORPH_OPEN, kernel, iterations=5)
close = cv2.morphologyEx(opening, cv2.MORPH_CLOSE, kernel, iterations=2)

plt.figure(figsize=(10,10))
plt.imshow(close, cmap="gray")

# %%
cnts = cv2.findContours(close, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

minimum_area = 200
average_cell_area = 650
connected_cell_area = 1000
cells = 0
for c in cnts:
    area = cv2.contourArea(c)
    if area > minimum_area:
        cv2.drawContours(original, [c], -1, (0,255,255), 2) # bgr values
        cells += 1
        x = c[0][0][0]
        y = c[0][0][1]
        cv2.putText(original, f"{cells}", (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 0, 255), 2)
# The code below is not to be used for this purpose because we consider connected "cells" as one
#         if area > connected_cell_area:
#             cells += math.ceil(area / average_cell_area)
#         else:
#             cells += 1
print('Cells: {}'.format(cells))
# Out:
# Cells: 76

# %%
plt.figure(figsize=(10,10))
plt.imshow(close)

# %%
plt.figure(figsize=(10,10))
plt.imshow(original)

# %%
original_RGB = cv2.cvtColor(original,cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(original_RGB)

# %%
# cnts[3] represents the large culture on the bottom left.
cv2.contourArea(cnts[3]) # area is 4258
math.ceil(4258 / average_cell_area) # number of individual 'cultures' in that mega culture (based on average area)
# Out:
# 7

# %%
len(cnts)
# Out:
# 66

# %%
c = cnts[0]

# %%
c[0][0][1]
# Out:
# 985
